# %% [markdown]
# # Example 1-1: Determining the Semimajor Axis from the Period
# ### _Fundamentals of Astrodynamics and Applications_, 5th Ed., 2022, pp. 31-32

# %% [markdown]
# This notebook demonstrates finding the semimajor axis from the orbital period, assuming a geosynchronous orbit.

# %% [markdown]
# ## Install and Import Libraries
# ---

# %% [markdown]
# First, install `valladopy` if it doesn't already exist in your environment:

# %%
# !pip install -r ../valladopy_version.txt
# Out:
# Collecting valladopy==0.4.1 (from -r ../valladopy_version.txt (line 1))
#   Using cached valladopy-0.4.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: numpy==1.26.4 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic==2.9.2 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (2.9.2)
# Requirement already satisfied: scipy==1.13.1 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from pydantic==2.9.2->valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from pydantic==2.9.2->valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/envs/vallado-env/lib/python3.12/site-packages (from pydantic==2.9.2->valladopy==0.4.1->-r ../valladopy_version.txt (line 1)) (4.12.2)
# Using cached valladopy-0.4.1-py3-none-any.whl (144 kB)
# Installing collected packages: valladopy
#   Attempting uninstall: valladopy
#     Found existing installation: valladopy 0.3.0
#     Uninstalling valladopy-0.3.0:
#       Successfully uninstalled valladopy-0.3.0
# Successfully installed valladopy-0.4.1

# %% [markdown]
# Then import `valladopy` to use its `constants` module:

# %%
from valladopy import constants as const

# %% [markdown]
# ## Problem Definition
# ---

# %% [markdown]
# GIVEN:&nbsp;A geosynchronous orbit<br>
# FIND:&nbsp;Semimajor axis, $e$

# %% [markdown]
# ## Solution
# ---

# %% [markdown]
# The orbital period $\mathcal{P}$ is defined from **Eq. 1-26**:
#
# $$
# \mathcal{P} = 2\pi \sqrt{\frac{a^3}{\mu}}
# $$
#
# Rearranging:
#
# $$
# a = \left( \mu \left( \frac{\mathcal{P}}{2\pi} \right)^2 \right)^{1/3}
# $$
# <br>
# where $\mathcal{P}$ is equal to 24 sidereal hours ($86,\!400 \div 1.002737909350795 = 86,\!164.090518$ sec), because the Earth completes one revolution through $2\pi$ radians in this amount of time. Be careful not to use 24 solar hours, which is a little *more* than one complete revolution.

# %%
a = (const.MU * (const.SIDERALDAY_SEC / const.TWOPI) ** 2) ** (1 / 3)

print(f'Semimajor axis:\t\t{a:.4f}\tkm')
print(f'\t\t\t{a/const.RE:.4f}\t\tEarth radii')
# Out:
# Semimajor axis:		42164.1696	km
# 			6.6107		Earth radii

# %% [markdown]
# A semimajor axis of ~42,164 km (or ~6.6 Earth radii) is consistent with a geostationary orbit.
